# %%
import numpy as np
import glob
import os

# %%
all_files = glob.glob(os.path.join('./quickdraw-dataset/', '*.npy'))

# %%
all_files
# Out:
# ['./quickdraw-dataset\\full_numpy_bitmap_aircraft carrier.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_airplane.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_alarm clock.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_ambulance.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_angel.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_animal migration.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_ant.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_anvil.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_apple.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_arm.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_asparagus.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_axe.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_backpack.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_banana.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_bandage.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_barn.npy',
#  './quickdraw-dataset\\full_numpy_bitmap_baseball bat.npy',
# ...

# %%
count = 0 # 测试
for file in all_files:
    data = np.load(file)
    data = data[:50000, :]
    path = './mini-quickdraw-dataset/' + os.path.basename(file)[18:]
    np.save(path, data)
    count += 1 # 测试

# %%
count
# Out:
# 345
